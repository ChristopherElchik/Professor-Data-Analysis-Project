# %%
import pandas as pd

df = pd.read_csv('data/combined_data.csv')
df
# Out:
#       Unnamed: 0                Name  \
# 0              0         Mary Lanier
# 1              1          Joy Morgan
# 2              2    Elizabeth Nelson
# 3              3        Wendy Warner
# 4              4    Charlotte  Farin
# ...          ...                 ...
# 2675        2675        Tushar Ghosh
# 2676        2676  Stephen Michielsen
# 2677        2677        James Watson
# 2678        2678       Rahul Vallabh
# 2679        2679    Pamela Banks-Lee
#
#                                         College  Quality Score  \
# 0                          College of Education            5.0
# 1      College of Agriculture and Life Sciences            4.2
# 2     College of Humanities and Social Sciences            4.8
# 3      College of Agriculture and Life Sciences            4.0
# 4      College of Agriculture and Life Sciences            2.8
# ...                                         ...            ...
# 2675                 Wilson College of Textiles            4.2
# ...
